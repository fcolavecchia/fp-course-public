# %% [markdown]
# ## Exercises

# %% [markdown]
# ### The _Kata_ of the traffic light
#
# Consider a vehicular traffic light that has three colored lights Red, Green, and Yellow. These lights come on for a certain number of seconds
# in a specific order: 🔴 ➡ 🟡 ➡ 🟢 ➡ 🟡 ➡ 🔴. In addition, there is always only one light on (it is not possible to have several lights
# on at the same time).
# As an example, assume the red light stays on for 45 seconds, the yellow light for 2 seconds, and the green light for 66 seconds,
# and that initially the traffic light turns red.
# Write a set of types and functions that allow  to describe the state of the semaphore.
# (That is, we are not interested at the moment in modeling the real evolution of the system in time.)
#
# - As a first step, define a suitable data type to describe the traffic light.
# - Analyze what are the transitions of the states of the lights, and propose the function(s) that allow the state to change, and the modifications necessary (or not) to the type of data that the semaphore describes.
# - Write a data type that can summarize the state of the traffic light and the transitions.
# - In some cases, typically at night in places with little traffic, the traffic light turns yellow intermittently. Add this new case to the problem model, and modify the functions accordingly.

# %% [markdown]
# ### Natural numbers
#
# Continuing with the example we saw in class, where a data type is proposed to describe natural numbers in the Peano style as:
#
# ```fsharp
# type Peano =
#     | Zero
#     | Succ of Peano
# ```
#
# Write functions that allow the addition and multiplication of two natural numbers defined as `Peano`.

# %% [markdown]
# ### Continuing with `MyList`
#
# Using the data type we saw in class
#
# ```fsharp
# type MyList =
#     | Empty
#     | Cons of int * MyList
# ```
#
# - Write a function `length` that gets the length of the list
#
# - Write a function `rev` that reorders the list from the last element to the first
#
# ```fsharp
# let exampleList = Cons (1, Cons (2, Cons (3, Empty)))
# // el resultado de rev exampleList debe ser
# // Cons (3, Cons (2, Cons (1, Empty)))
# ```
